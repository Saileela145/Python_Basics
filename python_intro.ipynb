# %%
print("hello,world")
# Out:
# hello,world

# %%
hello="im leela"
print(hello)
# Out:
# im leela

# %%
print(hello)
# Out:
# im leela

# %%
name=input("enter your name:")
print("hi",name)
# Out:
# enter your name: leela
# hi leela

# %% [markdown]
# this is space
# # Below is graph of diagonal line

# %%
import matplotlib.pyplot as plt
plt.plot([10,20,30,40],[10,20,30,40])
plt.show()

# %% [markdown]
# # welcome to my graph

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.plot([1,2,3,4],[1,2,3,4])
plt.plot([1,2,3,4],[1,2,3,4])
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()
