# %% [markdown]
# ## Matplotlib

# %% [markdown]
# -->It is an open source drawing library which supports rich drawing types
# -->It is used to draw 2D and 3D graphics
# ### Types of plots:
# 📍Bar Chart
# 📍Scatter Plot
# 📍Pie Chart
# 📍Histogram
# 📍Line Chart
# 📍Area Graph

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.26.4

# %%
"""Use NumPy to generate random data
"""
import numpy as np
x=np.linspace(0,10,25)
y=x*x+2
print(x)
print(y)
print(np.array([x,y]).reshape(25,2).reshape(2,25))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
# ...

# %%
""" It only take 1 command to draw
""" 
pylab.plot(x,y,'r')

# %%
""" Drawing a subgraph
"""
pylab.subplot(1,2,1) # The contents of the brackets represent(rows,columns,indexes)
pylab.plot(x,y,'r--')# The third parameter here determines color and line style
pylab.subplot(1,2,1)
pylab.plot(y,x,'g*-')

# %%
""" Drawing a subgrapg
"""
pylab.subplot() # The contents of the brackets represent(rows,columns,indexes)
pylab.plot(x,y,'r--')# The third parameter here determines color and line style
pylab.subplot(1,2,1)
pylab.plot(y,x,'g*-')

# %%
""" Drawing a subgrapg
"""
pylab.subplot() # The contents of the brackets represent(rows,columns,indexes)
pylab.plot(x,y,'r--')# The third parameter here determines color and line style
pylab.subplot(1,2,2)
pylab.plot(y,x,'g*-')

# %%
""" Drawing a subgrapg
"""
pylab.subplot() # The contents of the brackets represent(rows,columns,indexes)
pylab.plot(x,y,'r--')# The third parameter here determines color and line style
pylab.subplot()
pylab.plot(y,x,'g*-')

# %%
""" Drawing a subgrapg
"""
pylab.subplot(1,2,1) # The contents of the brackets represent(rows,columns,indexes)
pylab.plot(x,y,'r--')# The third parameter here determines color and line style
pylab.subplot(2,2,2)
pylab.plot(y,x,'g*-')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(2,2, 2)
pylab.plot(y,x,'g*-')
pylab.subplot(3,3, 3)
pylab.plot(y,x,'g*-')

# %% [markdown]
# ### Operator Description

# %% [markdown]
# ###### fig.add_axes()=Initializes subplot a=fig.add_subplot(222)
# ###### fig.b=plt.subplots(nrows=3,nclos=2)=Adds subplot
# ###### ax=plt.subplots(2,2)=Creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig =plt.figure()
axis=fig.add_axes([0.5,0.1,0.8,0.8])# Control the left,right,width,height of the convas(from 0 to 1)
axis.plot(x,y,'r')

# %%
# Again we can draw subgraphs
fig,axes=plt.subplots(nrows=1,ncols=2)#submap is of 1 row,2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# we can also draw a picture,or graph,inside another graph
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])#big axes
axes2=fig.add_axes([0.2,0.6,0.2,0.2])# Small canvas
axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

# %%
fig=plt.figure(figsize=(16,9))
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig=plt.figure(figsize=(16,9),dpi=300)# New graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig=plt.figure(figsize=(16,9),dpi=600)# New graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig,axes=plt.subplots(figsize=(16,9),dpi=50)
axes.plot(x,y,'r')

# %%
fig,axes=plt.subplots()
axes.set_title("title")
axes.plot(x,y,'r')

# %%
fig,axes=plt.subplots()
axes.set_title("title")
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")
axes.plot(x,y,'r')

# %%
ax.legend(["label","label2"])
fig,axes=plt.subplots()
axes.set_title("title of the graph")
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.legend(["y=x**2","y=x**3"],loc=6)

# %%
# In Matplotlib,you can set other properties such as line color,transparency,and more.
fig,axes=plt.subplots(dpi=150)
axes.plot(x,x**2,color='red',alpha=.3)
axes.plot(x,x+2,color="#1155dd",alpha=.3)
axes.plot(x,x+3,color="pink",alpha=.3)

# %%
fig,ax=plt.subplots(dpi=100)
## Line width
ax.plot(x,x+1,color='blue',linewidth=0.25)
ax.plot(x,x+2,color='blue',linewidth=1)
ax.plot(x,x+3,color='blue',linewidth=1.5)
ax.plot(x,x+4,color='blue',linewidth=2)

# %%
fig,ax=plt.subplots(dpi=100)
## Line width
ax.plot(x,x+1,color='blue',lw=0.6, linestyle='-')
ax.plot(x,x+2,color='blue',lw=1, linestyle='-.')
ax.plot(x,x+3,color='blue',lw=1.5, linestyle=':')
ax.plot(x,x+4,color='blue',lw=2, linestyle=':')
line,=ax.plot(x,x+8,color="black",lw=1.50)
line.set_dashes([2,4,6,8])

# %%
fig,ax=plt.subplots(dpi=100)
## Line width
ax.plot(x,x+1,color='blue',lw=0.6, linestyle='-')
ax.plot(x,x+2,color='blue',lw=1, linestyle='-.')
ax.plot(x,x+3,color='blue',lw=1.5, linestyle=':')
ax.plot(x,x+4,color='blue',lw=2, linestyle=':')
line,=ax.plot(x,x+8,color="black",lw=1.50)
line.set_dashes([2,4,6,8])
line,=ax.plot(x,x+4,color="black",lw=1.50)
line.set_dashes([2,4,8,10])
line,=ax.plot(x,x+4,color="black",lw=1.50)
line.set_dashes([2,4,30,30])

# %%
fig,ax=plt.subplots(dpi=100)
## Line width
ax.plot(x,x+1,color='blue')
ax.plot(x,x+2,color='blue')
ax.plot(x,x+3,color='blue')
ax.plot(x,x+4,color='blue')

# %%
fig,ax=plt.subplots(dpi=100)
## Line width
ax.plot(x,x+1,color='blue',marker='o')
ax.plot(x,x+2,color='blue',marker='+')
ax.plot(x,x+3,color='blue',marker='s')
ax.plot(x,x+4,color='blue',marker='1')
ax.plot(x,x+5,color="blue",marker='o',markersize=10)
ax.plot(x,x+6,color="blue",marker='s',markerfacecolor='red')
ax.plot(x,x+6,color="blue",marker='o',markerfacecolor='yellow',markersize=8)

# %%
""" set the canvas grid axis range
"""
fig,Axes=plt.subplots(1,2,figsize=(10,5))
Axes[0].plot(x,x**2,x,x**3,lw=2)
Axes[0].grid(True)

# %%
""" set the canvas grid axis range
"""
fig,Axes=plt.subplots(1,2,figsize=(10,5))
Axes[0].plot(x,x**2,x,x**3,lw=2)
Axes[0].grid(True)
Axes[1].plot(x,x**2,x,x**3,lw=2)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %% [markdown]
# ## Other 2D Graphics

# %%
n=np.array([0,1,2,3,4,5])
fig,axes=plt.subplots(1,4,figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))

# %%
n=np.array([0,1,2,3,4,5])
fig,axes=plt.subplots(1,4,figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n,n**2,lw=2)

# %%
n=np.array([0,1,2,3,4,5])
fig,axes=plt.subplots(1,4,figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n,n**2,lw=2)
axes[2].set_title("bar")
axes[2].bar(n,n**2,align="center",width=0.6,alpha=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
n=np.array([0,1,2,3,4,5])
fig,axes=plt.subplots(1,4,figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n,n**2,lw=2)
axes[2].set_title("bar")
axes[2].bar(n,n**2,align="center",width=.5,alpha=0.5)
axes[3].set_title("fill_between")
axes[3].fill_between(x,x**2,x**3,color="green",alpha=0.5)

# %%
"""Draw a radar chart
"""
fig=plt.figure(figsize=(6,6))
ax=fig.add_axes([0.0,0.0,.6,.6],polar=True)
t=np.linspace(0,2*np.pi,100)
ax.plot(t,t*2,color="blue",lw=3)

# %%
"""Draw a radar chart
"""
fig=plt.figure(figsize=(6,6))
ax=fig.add_axes([0.0,0.0,.6,.6],polar=True)
t=np.linspace(0,2*np.pi,100)
ax.plot(t,t,color="blue",lw=3)

# %%
"""Draw a radar chart
"""
fig=plt.figure(figsize=(6,6))
ax=fig.add_axes([0.0,0.0,.6,.6],polar=True)

# %%
""" draw a radar chart
"""
n=np.random.randn(100000)
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("default histogram")
axes[0].hist(n)
# Out:
# (array([8.70000e+01, 2.42600e+03, 2.89610e+04, 1.49856e+05, 3.33957e+05,
#         3.23375e+05, 1.34903e+05, 2.44880e+04, 1.87700e+03, 7.00000e+01]),
#  array([-4.71207751, -3.76220646, -2.8123354 , -1.86246434, -0.91259329,
#          0.03727777,  0.98714883,  1.93701988,  2.88689094,  3.83676199,
#          4.78663305]),
#  <BarContainer object of 10 artists>)

# %%
""" draw a radar chart
"""
n=np.random.randn(100000)
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("default histogram")
axes[0].hist(n)
axes[1].set_title("cummulative detailed histogram")
axes[1].hist(n,cumulative=True,bins=50)
# Out:
# (array([1.0000e+00, 3.0000e+00, 4.0000e+00, 7.0000e+00, 9.0000e+00,
#         1.9000e+01, 4.3000e+01, 7.3000e+01, 1.5300e+02, 2.8100e+02,
#         5.1500e+02, 8.8500e+02, 1.4700e+03, 2.3070e+03, 3.5470e+03,
#         5.2530e+03, 7.5380e+03, 1.0505e+04, 1.4299e+04, 1.8956e+04,
#         2.4479e+04, 3.0545e+04, 3.7269e+04, 4.4441e+04, 5.1916e+04,
#         5.9216e+04, 6.6274e+04, 7.2907e+04, 7.8616e+04, 8.3622e+04,
#         8.7816e+04, 9.1186e+04, 9.3780e+04, 9.5758e+04, 9.7181e+04,
#         9.8191e+04, 9.8851e+04, 9.9309e+04, 9.9578e+04, 9.9746e+04,
#         9.9864e+04, 9.9942e+04, 9.9969e+04, 9.9987e+04, 9.9993e+04,
#         9.9997e+04, 9.9999e+04, 9.9999e+04, 9.9999e+04, 1.0000e+05]),
#  array([-4.58325602, -4.397981  , -4.21270597, -4.02743095, -3.84215593,
#         -3.6568809 , -3.47160588, -3.28633086, -3.10105583, -2.91578081,
#         -2.73050579, -2.54523076, -2.35995574, -2.17468071, -1.98940569,
# ...

# %%
""" draw a radar chart
"""
n=np.random.randn(100000)
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("default histogram")
axes[0].hist(n)
axes[1].set_title("cummulative detailed histogram")
axes[1].hist(n,cumulative=True,bins=10)
# Out:
# (array([8.6000e+01, 1.1280e+03, 6.9730e+03, 2.5303e+04, 5.6026e+04,
#         8.3264e+04, 9.6303e+04, 9.9562e+04, 9.9977e+04, 1.0000e+05]),
#  array([-3.92759027, -3.11116384, -2.29473741, -1.47831098, -0.66188454,
#          0.15454189,  0.97096832,  1.78739475,  2.60382119,  3.42024762,
#          4.23667405]),
#  <BarContainer object of 10 artists>)

# %%
""" draw a radar chart
"""
n=np.random.randn(100000)
fig,axes=plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("default histogram")
axes[0].hist(n)
axes[1].set_title("cummulative detailed histogram")
axes[1].hist(n,bins=10)
# Out:
# (array([3.6000e+01, 5.4600e+02, 3.8610e+03, 1.5063e+04, 2.9708e+04,
#         3.0002e+04, 1.5820e+04, 4.3430e+03, 5.9300e+02, 2.8000e+01]),
#  array([-4.22910831, -3.38852047, -2.54793264, -1.70734481, -0.86675698,
#         -0.02616915,  0.81441868,  1.65500651,  2.49559434,  3.33618217,
#          4.17677   ]),
#  <BarContainer object of 10 artists>)

# %%
# Draw contour image
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
delta=0.025
x=np.arange(-3.0,3.0,delta)
y=np.arange(-2.0,2.0,delta)
X,Y=np.meshgrid(x,y)
Z1=np.exp(-X**2-Y**2)
Z2=np.exp(-(X-1)**2-(Y-1)**2)
Z=(Z1-Z2)*2
print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig,ax=plt.subplots()
CS=ax.contour(X,Y,Z)
ax.clabel(CS,inline=1,fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')
